# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
(train_data,train_labels),(test_data,test_labels) = keras.datasets.imdb.load_data(num_words=5000)

train_data = keras.preprocessing.sequence.pad_sequences(train_data,maxlen=512)
test_data =  keras.preprocessing.sequence.pad_sequences(test_data,maxlen=512)

# %%
def create_model(hidden_layers, units, loss_function, activation,dropout):
  model = keras.Sequential()
  model.add(layers.Embedding(10000, 16))
  model.add(layers.GlobalAveragePooling1D())
  for _ in range(hidden_layers):
        model.add(layers.Dense(units, activation=activation))
        model.add(layers.Dropout(dropout))
  model.add(layers.Dense(1, activation='sigmoid'))
  model.compile(optimizer='adam',
                  loss=loss_function,
                  metrics=['accuracy'])
  return model

# %% [markdown]
# Number of hidden layers 3 and number of units 64 and mse loss function

# %%
model = create_model(hidden_layers=3, units=64, loss_function='mse', activation='tanh',dropout=0.5)

# Train the model
history = model.fit(train_data,
                    train_labels,
                    epochs=20,
                    batch_size=512,
                    validation_split=0.2,
                    verbose=2)

results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_history(history)


results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Epoch 1/20
# 40/40 - 4s - 94ms/step - accuracy: 0.5429 - loss: 0.2462 - val_accuracy: 0.5178 - val_loss: 0.2956
# Epoch 2/20
# 40/40 - 1s - 36ms/step - accuracy: 0.6054 - loss: 0.2396 - val_accuracy: 0.7200 - val_loss: 0.2138
# Epoch 3/20
# 40/40 - 2s - 57ms/step - accuracy: 0.6571 - loss: 0.2264 - val_accuracy: 0.5734 - val_loss: 0.2324
# Epoch 4/20
# 40/40 - 1s - 31ms/step - accuracy: 0.6926 - loss: 0.2128 - val_accuracy: 0.7360 - val_loss: 0.1802
# Epoch 5/20
# 40/40 - 1s - 31ms/step - accuracy: 0.7293 - loss: 0.2005 - val_accuracy: 0.7954 - val_loss: 0.1519
# Epoch 6/20
# 40/40 - 1s - 36ms/step - accuracy: 0.8094 - loss: 0.1399 - val_accuracy: 0.8012 - val_loss: 0.1334
# Epoch 7/20
# 40/40 - 3s - 64ms/step - accuracy: 0.8183 - loss: 0.1264 - val_accuracy: 0.6446 - val_loss: 0.2625
# Epoch 8/20
# 40/40 - 4s - 95ms/step - accuracy: 0.7494 - loss: 0.1759 - val_accuracy: 0.8598 - val_loss: 0.1223
# Epoch 9/20
# ...

# %% [markdown]
# Number of hidden layers 3 and number of units 32 and mse loss function

# %%
model = create_model(hidden_layers=3, units=32, loss_function='mse', activation='tanh',dropout=0.5)

# Train the model
history = model.fit(train_data,
                    train_labels,
                    epochs=20,
                    batch_size=512,
                    validation_split=0.2,
                    verbose=2)

results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_history(history)

results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Epoch 1/20
# 40/40 - 3s - 77ms/step - accuracy: 0.5091 - loss: 0.2497 - val_accuracy: 0.5148 - val_loss: 0.2486
# Epoch 2/20
# 40/40 - 2s - 60ms/step - accuracy: 0.5863 - loss: 0.2397 - val_accuracy: 0.5994 - val_loss: 0.2255
# Epoch 3/20
# 40/40 - 1s - 30ms/step - accuracy: 0.6930 - loss: 0.1945 - val_accuracy: 0.7566 - val_loss: 0.1599
# Epoch 4/20
# 40/40 - 1s - 32ms/step - accuracy: 0.7768 - loss: 0.1512 - val_accuracy: 0.6384 - val_loss: 0.2504
# Epoch 5/20
# 40/40 - 1s - 31ms/step - accuracy: 0.5576 - loss: 0.4130 - val_accuracy: 0.5342 - val_loss: 0.4498
# Epoch 6/20
# 40/40 - 2s - 44ms/step - accuracy: 0.6467 - loss: 0.2726 - val_accuracy: 0.8218 - val_loss: 0.1672
# Epoch 7/20
# 40/40 - 2s - 51ms/step - accuracy: 0.8209 - loss: 0.1442 - val_accuracy: 0.8500 - val_loss: 0.1239
# Epoch 8/20
# 40/40 - 2s - 43ms/step - accuracy: 0.8438 - loss: 0.1168 - val_accuracy: 0.7684 - val_loss: 0.1536
# Epoch 9/20
# ...

# %% [markdown]
# Number of hidden layers 1 and number of units 32 and mse loss function

# %%
model = create_model(hidden_layers=1, units=32, loss_function='mse', activation='tanh',dropout=0.5)

# Train the model
history = model.fit(train_data,
                    train_labels,
                    epochs=20,
                    batch_size=512,
                    validation_split=0.2,
                    verbose=2)

results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_history(history)


results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Epoch 1/20
# 40/40 - 4s - 96ms/step - accuracy: 0.5396 - loss: 0.2489 - val_accuracy: 0.5100 - val_loss: 0.2473
# Epoch 2/20
# 40/40 - 1s - 31ms/step - accuracy: 0.5845 - loss: 0.2426 - val_accuracy: 0.5824 - val_loss: 0.2361
# Epoch 3/20
# 40/40 - 1s - 29ms/step - accuracy: 0.6816 - loss: 0.2243 - val_accuracy: 0.6556 - val_loss: 0.2118
# Epoch 4/20
# 40/40 - 1s - 31ms/step - accuracy: 0.7413 - loss: 0.1953 - val_accuracy: 0.7740 - val_loss: 0.1776
# Epoch 5/20
# 40/40 - 1s - 32ms/step - accuracy: 0.7879 - loss: 0.1661 - val_accuracy: 0.8230 - val_loss: 0.1507
# Epoch 6/20
# 40/40 - 1s - 32ms/step - accuracy: 0.8141 - loss: 0.1445 - val_accuracy: 0.8096 - val_loss: 0.1409
# Epoch 7/20
# 40/40 - 1s - 31ms/step - accuracy: 0.8346 - loss: 0.1285 - val_accuracy: 0.8380 - val_loss: 0.1266
# Epoch 8/20
# 40/40 - 1s - 31ms/step - accuracy: 0.8514 - loss: 0.1160 - val_accuracy: 0.6960 - val_loss: 0.1954
# Epoch 9/20
# ...

# %% [markdown]
# Number of hidden layers 1 and number of units 64 and mse loss function

# %%
model = create_model(hidden_layers=1, units=64, loss_function='mse', activation='tanh',dropout=0.5)

# Train the model
history = model.fit(train_data,
                    train_labels,
                    epochs=20,
                    batch_size=512,
                    validation_split=0.2,
                    verbose=2)

results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_history(history)

results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Epoch 1/20
# 40/40 - 2s - 62ms/step - accuracy: 0.5204 - loss: 0.2492 - val_accuracy: 0.5562 - val_loss: 0.2471
# Epoch 2/20
# 40/40 - 3s - 67ms/step - accuracy: 0.5997 - loss: 0.2420 - val_accuracy: 0.6308 - val_loss: 0.2327
# Epoch 3/20
# 40/40 - 3s - 63ms/step - accuracy: 0.6442 - loss: 0.2230 - val_accuracy: 0.5730 - val_loss: 0.2394
# Epoch 4/20
# 40/40 - 1s - 29ms/step - accuracy: 0.7205 - loss: 0.1952 - val_accuracy: 0.7898 - val_loss: 0.1723
# Epoch 5/20
# 40/40 - 1s - 29ms/step - accuracy: 0.8034 - loss: 0.1579 - val_accuracy: 0.8098 - val_loss: 0.1460
# Epoch 6/20
# 40/40 - 1s - 31ms/step - accuracy: 0.8175 - loss: 0.1365 - val_accuracy: 0.7642 - val_loss: 0.1508
# Epoch 7/20
# 40/40 - 1s - 31ms/step - accuracy: 0.7757 - loss: 0.1497 - val_accuracy: 0.8396 - val_loss: 0.1244
# Epoch 8/20
# 40/40 - 1s - 31ms/step - accuracy: 0.8425 - loss: 0.1177 - val_accuracy: 0.8470 - val_loss: 0.1164
# Epoch 9/20
# ...

# %%
results = model.evaluate(test_data, test_labels)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8054 - loss: 0.1359
# Test Loss: 0.13359159231185913, Test Accuracy: 0.8069599866867065
